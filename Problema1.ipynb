# %% [markdown]
# # Ejercicio - Busqueda de Alojamiento en Airbnb.
#
# Supongamos que somos un agente de [Airbnb](http://www.airbnb.com) localizado en Lisboa, y tenemos que atender peticiones de varios clientes. Tenemos un archivo llamado `airbnb.csv` (en la carpeta data) donde tenemos información de todos los alojamientos de Airbnb en Lisboa.

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df_airbnb = pd.read_csv("./data/airbnb.csv")

# %%
df_airbnb.head()
# Out:
#    room_id  host_id        room_type       neighborhood  reviews  \
# 0     6499    14455  Entire home/apt              Belém        8
# 1    17031    66015  Entire home/apt           Alvalade        0
# 2    25659   107347  Entire home/apt  Santa Maria Maior       63
# 3    29248   125768  Entire home/apt  Santa Maria Maior      225
# 4    29396   126415  Entire home/apt  Santa Maria Maior      132
#
#    overall_satisfaction  accommodates  bedrooms  price
# 0                   5.0             2       1.0   57.0
# 1                   0.0             2       1.0   46.0
# 2                   5.0             3       1.0   69.0
# 3                   4.5             4       1.0   58.0
# 4                   5.0             4       1.0   67.0

# %%
df_airbnb.dtypes
# Out:
# room_id                   int64
# host_id                   int64
# room_type                object
# neighborhood             object
# reviews                   int64
# overall_satisfaction    float64
# accommodates              int64
# bedrooms                float64
# price                   float64
# dtype: object

# %% [markdown]
# En concreto el dataset tiene las siguientes variables:
# - room_id: el identificador de la propiedad
# - host_id: el identificador del dueño de la propiedad
# - room_type: tipo de propiedad (vivienda completa/(habitacion para compartir/habitación privada)
# - neighborhood: el barrio de Lisboa
# - reviews: El numero de opiniones
# - overall_satisfaction: Puntuacion media del apartamento
# - accommodates: El numero de personas que se pueden alojar en la propiedad
# - bedrooms: El número de habitaciones
# - price: El precio (en euros) por noche

# %% [markdown]
# ## Usando Pandas

# %% [markdown]
# ### Caso 1.
#
# Alicia va a ir a Lisboa durante una semana con su marido y sus 2 hijos. Están buscando un apartamento con habitaciones separadas para los padres y los hijos. No les importa donde alojarse o el precio, simplemente quieren tener una experiencia agradable. Esto significa que solo aceptan lugares con más de 10 críticas con una puntuación mayor de 4. Cuando seleccionemos habitaciones para Alicia, tenemos que asegurarnos de ordenar las habitaciones de mejor a peor puntuación. Para aquellas habitaciones que tienen la misma puntuación, debemos mostrar antes aquellas con más críticas. Debemos darle 3 alternativas.

# %%
import pandas as pd
df_airbnb = pd.read_csv("./data/airbnb.csv",index_col=0)
df_airbnb.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0
# 29248                     4.5             4       1.0   58.0
# 29396                     5.0             4       1.0   67.0

# %%
filtro = df_airbnb[(df_airbnb['reviews']>10) & (df_airbnb['overall_satisfaction']>4)]
filtro.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
# 29720     128075  Entire home/apt            Estrela       14
# 29872     128698  Entire home/apt          Alcântara       25
#
#          overall_satisfaction  accommodates  bedrooms   price
# room_id
# 25659                     5.0             3       1.0    69.0
# 29248                     4.5             4       1.0    58.0
# 29396                     5.0             4       1.0    67.0
# 29720                     5.0            16       9.0  1154.0
# 29872                     5.0             2       1.0    75.0

# %%
by_overall_satisfaction = filtro.sort_values('overall_satisfaction', ascending=False)
by_overall_satisfaction.head()
# Out:
#            host_id        room_type       neighborhood  reviews  \
# room_id
# 44043       192830  Entire home/apt  Santa Maria Maior      316
# 18355475  74171605  Entire home/apt       Misericórdia       14
# 25659       107347  Entire home/apt  Santa Maria Maior       63
# 18076114  21980829  Entire home/apt  Santa Maria Maior       14
# 18103988   7910883     Private room  Santa Maria Maior       14
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 44043                      5.0             7       3.0   80.0
# 18355475                   5.0             6       2.0   79.0
# 25659                      5.0             3       1.0   69.0
# 18076114                   5.0             4       1.0   67.0
# 18103988                   5.0             2       1.0   35.0

# %% [markdown]
# ### Caso 2
#
# Roberto es un casero que tiene una casa en Airbnb. De vez en cuando nos llama preguntando sobre cuales son las críticas de su alojamiento. Hoy está particularmente enfadado, ya que su hermana Clara ha puesto una casa en Airbnb y Roberto quiere asegurarse de que su casa tiene más críticas que las de Clara. Tenemos que crear un dataframe con las propiedades de ambos. Las id de las casas de Roberto y Clara son 97503 y 90387  respectivamente. Finalmente guardamos este dataframe como excel llamado "roberto.xls

# %%
import pandas as pd
df_airbnb = pd.read_csv("./data/airbnb.csv",index_col=0)
df_airbnb.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0
# 29248                     4.5             4       1.0   58.0
# 29396                     5.0             4       1.0   67.0

# %%
filtro2 = df_airbnb[(df_airbnb['host_id'] == 515924) | (df_airbnb['host_id'] == 490050)]
filtro2.head(2)
# Out:
#          host_id     room_type   neighborhood  reviews  overall_satisfaction  \
# room_id
# 90387     490050  Private room  Santo António      204                   5.0
# 97503     515924  Private room  Santo António       39                   4.0
#
#          accommodates  bedrooms  price
# room_id
# 90387               2       1.0   46.0
# 97503               2       1.0   26.0

# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 5.3 MB/s eta 0:00:00:00:01
# ...

# %%
filtro2.to_excel("roberto.xls", engine='openpyxl' ,sheet_name='roberto',index=False)
print("Archivo 'roberto.xls' guardado correctamente.")
# Out:
# Archivo 'roberto.xls' guardado correctamente.

# %% [markdown]
# ### Caso 3
#
# Diana va a Lisboa a pasar 3 noches y quiere conocer a gente nueva. Tiene un presupuesto de 50€ para su alojamiento. Debemos buscarle las 10 propiedades más baratas, dandole preferencia a aquellas que sean habitaciones compartidas *(room_type == Shared room)*, y para aquellas viviendas compartidas debemos elegir aquellas con mejor puntuación.

# %%
import pandas as pd
df_airbnb = pd.read_csv("./data/airbnb.csv",index_col=0)
df_airbnb.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0
# 29248                     4.5             4       1.0   58.0
# 29396                     5.0             4       1.0   67.0

# %%
filtro3 = df_airbnb[(df_airbnb['price'] < 50) & (df_airbnb['room_type'] == 'Shared room')]
filtro3.head(10)
# Out:
#           host_id    room_type      neighborhood  reviews  \
# room_id
# 286153    1489229  Shared room         Campolide       29
# 697493    3573506  Shared room  Campo de Ourique        0
# 1179457   5799522  Shared room     Santo António       42
# 1365083   6401752  Shared room           Areeiro       51
# 1380975   6855202  Shared room     Santo António        2
# 1830748   9575555  Shared room      Misericórdia       36
# 2376711  11481927  Shared room       São Vicente        7
# 2376715  11481927  Shared room       São Vicente       38
# 2382263  11481927  Shared room       São Vicente        4
# 2557813  13060370  Shared room           Arroios        0
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 286153                    4.5             2       1.0   21.0
# 697493                    0.0            10       1.0   18.0
# 1179457                   4.0            16       1.0   10.0
# 1365083                   4.5             4       1.0   18.0
# ...

# %%
puntuacion = filtro3.sort_values('overall_satisfaction', ascending=False)
puntuacion.head(10)
# Out:
#            host_id    room_type    neighborhood  reviews  \
# room_id
# 11427995  32344156  Shared room    Misericórdia       21
# 11523225  58899339  Shared room  Avenidas Novas        4
# 10397682  32344156  Shared room    Misericórdia       15
# 10172929  52218341  Shared room         Areeiro       17
# 17497074  25913998  Shared room         Arroios        7
# 14719962  40574313  Shared room  Avenidas Novas        4
# 13570032  78249982  Shared room    Misericórdia        8
# 16150682  58899339  Shared room  Avenidas Novas        4
# 12826411   6981742  Shared room        Alvalade       12
# 13078189  72524317  Shared room           Ajuda        7
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 11427995                   5.0             8       1.0   18.0
# 11523225                   5.0             9       1.0   23.0
# 10397682                   5.0             8       1.0   13.0
# 10172929                   5.0             1       1.0   20.0
# ...
